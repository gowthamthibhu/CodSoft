# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train=pd.read_csv(r"C:\Users\gowth\OneDrive\Desktop\ProgrammingProjects\CodSoft\credit_card\dataset\fraudTrain.csv")
df_test=pd.read_csv(r"C:\Users\gowth\OneDrive\Desktop\ProgrammingProjects\CodSoft\credit_card\dataset\fraudTest.csv")

# %%
df = pd.concat([df_train, df_test])
df.shape[0]
# Out:
# 1852394

# %%
df.groupby("is_fraud").count()["cc_num"].plot(kind = "bar")
# Out:
# <Axes: xlabel='is_fraud'>
